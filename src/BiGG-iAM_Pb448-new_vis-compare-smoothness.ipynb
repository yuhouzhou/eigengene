# %%
# Specification
# https://github.com/SBRG/bigg_models/wiki/BiGG-Models-ID-Specification-and-Guidelines

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx
import json

# %%
with open('../data/iAM_Pb448.json', 'r') as file:
    models = json.loads(file.read())

# %% [markdown]
# ## Data Inspection

# %%
type(models)
# Out:
# dict

# %%
len(models)
# Out:
# 6

# %%
models.keys()
# Out:
# dict_keys(['metabolites', 'reactions', 'genes', 'id', 'compartments', 'version'])

# %%
models['id']
# Out:
# 'iAM_Pb448'

# %%
models['version']
# Out:
# '1'

# %%
models['compartments']
# Out:
# {'c': 'cytosol',
#  'e': 'extracellular space',
#  'g': 'golgi apparatus',
#  'h': 'chloroplast',
#  'l': 'lysosome',
#  'm': 'mitochondria',
#  'r': 'endoplasmic reticulum'}

# %%
models['reactions'][:2]
# Out:
# [{'id': 'EX_h2o_e',
#   'name': 'H2O exchange',
#   'metabolites': {'h2o_e': -1.0},
#   'lower_bound': -1.0,
#   'upper_bound': 1000000.0,
#   'gene_reaction_rule': '',
#   'subsystem': 'Extracellular exchange',
#   'notes': {'original_bigg_ids': ['EX_h2o_LPAREN_e_RPAREN_']},
#   'annotation': {'bigg.reaction': ['EX_h2o_e'],
#    'biocyc': ['META:TRANS-RXN-145', 'META:TRANS-RXN0-547'],
#    'metanetx.reaction': ['MNXR98641'],
#    'reactome.reaction': ['R-ATH-507868',
#     'R-CFA-432054',
#     'R-CFA-432010',
#     'R-RNO-507868',
#     'R-OSA-432065',
#     'R-GGA-432010',
#     'R-SPO-445714',
#     'R-PFA-445714',
#     'R-CFA-432065',
#     'R-GGA-432067',
#     'R-TGU-432054',
#     'R-TGU-445714',
#     'R-OSA-507868',
#     'R-DRE-507868',
#     'R-SPO-507868',
#     'R-BTA-432054',
#     'R-GGA-507870',
#     'R-OSA-432010',
#     'R-DME-432065',
#     'R-DRE-432067',
#     'R-PFA-507868',
#     'R-SSC-432054',
#     'R-HSA-432065',
#     'R-OSA-507870',
#     'R-HSA-432054',
#     'R-SSC-432065',
#     'R-CEL-507868',
#     'R-XTR-507868',
#     'R-ATH-507870',
#     'R-SCE-432065',
#     'R-BTA-507870',
#     'R-DME-432010',
#     'R-CFA-445714',
#     'R-DRE-445714',
#     'R-BTA-507868',
#     'R-GGA-507868',
#     'R-RNO-432054',
#     'R-RNO-432010',
#     'R-SSC-432067',
#     'R-CEL-445714',
#     'R-DDI-432065',
#     'R-ATH-432010',
#     'R-SCE-432054',
#     'R-MMU-432065',
#     'R-MMU-445714',
#     'R-GGA-432065',
#     'R-HSA-432067',
#     'R-SSC-507870',
#     'R-SCE-432067',
#     'R-RNO-507870',
#     'R-DME-432054',
#     'R-ATH-432067',
#     'R-BTA-445714',
#     'R-DRE-507870',
#     'R-DME-507868',
#     'R-DME-507870',
#     'R-DRE-432010',
#     'R-MMU-432010',
#     'R-HSA-445714',
#     'R-OSA-432054',
#     'R-RNO-432067',
#     'R-TGU-432010',
#     'R-TGU-507868',
#     'R-DDI-432054',
#     'R-PFA-507870',
#     'R-HSA-507870',
#     'R-XTR-432067',
#     'R-HSA-432010',
#     'R-SSC-507868',
#     'R-SCE-507870',
#     'R-CEL-507870',
#     'R-DDI-507868',
#     'R-DRE-432054',
#     'R-XTR-507870',
#     'R-DDI-432010',
#     'R-BTA-432065',
#     'R-CFA-432067',
#     'R-OSA-432067',
#     'R-ATH-432065',
#     'R-GGA-445714',
#     'R-SCE-507868',
#     'R-TGU-432065',
#     'R-MMU-432067',
#     'R-TGU-507870',
#     'R-CFA-507870',
#     'R-RNO-432065',
#     'R-MMU-432054',
#     'R-MMU-507868',
#     'R-SPO-507870',
#     'R-SCE-432010',
#     'R-MMU-507870',
#     'R-SSC-445714',
#     'R-HSA-507868',
#     'R-DME-432067',
#     'R-SSC-432010',
#     'R-TGU-432067',
#     'R-GGA-432054',
#     'R-BTA-432010',
#     'R-SCE-445714',
#     'R-DDI-507870',
#     'R-ATH-432054',
#     'R-DDI-432067',
#     'R-XTR-445714',
#     'R-BTA-432067',
#     'R-CFA-507868',
#     'R-RNO-445714'],
#    'rhea': ['29668', '29669', '29667', '29670'],
#    'sbo': 'SBO:0000627',
#    'seed.reaction': ['rxn08687',
#     'rxn08686',
#     'rxn09745',
#     'rxn09838',
#     'rxn09874',
#     'rxn09812',
#     'rxn09643',
#     'rxn05319']}},
#  {'id': 'ACCOAC_h',
#   'name': 'Acetyl-CoA-carboxylase',
#   'metabolites': {'accoa_h': -1.0,
#    'adp_h': 1.0,
#    'atp_h': -1.0,
#    'h_h': 1.0,
#    'hco3_h': -1.0,
#    'malcoa_h': 1.0,
#    'pi_h': 1.0},
#   'lower_bound': 0.0,
#   'upper_bound': 1000000.0,
#   'gene_reaction_rule': '((PBANKA_132360 or PBANKA_051100) or PBANKA_133280) and (PBANKA_051100 or PBANKA_132360)',
#   'notes': {'original_bigg_ids': ['ACCOACc']},
#   'annotation': {'bigg.reaction': ['ACCOAC_h'], 'sbo': 'SBO:0000176'}}]

# %%
models['metabolites'][:2]
# Out:
# [{'id': 'cdpdag_pf_18_1_20_4_c',
#   'name': 'CDP diacylglycerol(plasmodium,C18:1,C20:4)',
#   'compartment': 'c',
#   'charge': -2,
#   'formula': 'C50H81N3O15P2',
#   'notes': {'original_bigg_ids': ['cdpdag_pf_18_1_20_4_c']},
#   'annotation': {'bigg.metabolite': ['cdpdag_pf_18_1_20_4'],
#    'sbo': 'SBO:0000247'}},
#  {'id': 'pa_pf_18_1_20_4_c',
#   'name': 'Phosphatidic acid(plasmodium,C18:1,C20:4)',
#   'compartment': 'c',
#   'charge': -2,
#   'formula': 'C41H69O8P',
#   'notes': {'original_bigg_ids': ['pa_pf_18_1_20_4_c']},
#   'annotation': {'bigg.metabolite': ['pa_pf_18_1_20_4'],
#    'sbo': 'SBO:0000247'}}]

# %% [markdown]
# ## 'gene reaction rule' in 'reactions'

# %%
for i, reaction in enumerate(models['reactions']):
    if i < 60:
        print(reaction['gene_reaction_rule'])
    else:
        break
# Out:
# ((PBANKA_132360 or PBANKA_051100) or PBANKA_133280) and (PBANKA_051100 or PBANKA_132360)
# PBANKA_051980
#
# PBANKA_091820
# PBANKA_081210 or PBANKA_112360
# PBANKA_030820
# PBANKA_135520
# PBANKA_135520
# PBANKA_135520
# PBANKA_135520
# PBANKA_101440
# PBANKA_052160
# PBANKA_112650
# PBANKA_093610
#
# PBANKA_051360
# PBANKA_132210
# PBANKA_082330
# PBANKA_136010
# PBANKA_120720 or PBANKA_020280 or PBANKA_040430 or PBANKA_071390
# PBANKA_071760
# PBANKA_051690
# PBANKA_103750 or PBANKA_122760
# PBANKA_136010
#
#
# PBANKA_030430
# PBANKA_030430
# PBANKA_113110
# PBANKA_130820
# PBANKA_130820
# PBANKA_130820
# PBANKA_130820
# PBANKA_130820
# PBANKA_130820
# PBANKA_130820
# PBANKA_130820
# PBANKA_130820
#
#
#
# PBANKA_123560
# PBANKA_070670 or PBANKA_143870
# (PBANKA_071010 or PBANKA_141110) and PBANKA_141910 and (PBANKA_071490 or PBANKA_144690)
# PBANKA_070670
# PBANKA_070670
#
# PBANKA_070670
# PBANKA_144100
#
#
# PBANKA_145920
# PBANKA_060690 or PBANKA_144610 or PBANKA_030670 or PBANKA_111510 or PBANKA_091590 or PBANKA_1128300
# PBANKA_114050
# PBANKA_130440
#
#
# PBANKA_145500

# %% [markdown]
# From above, we see that some reactions are ruled by some genes, and some reactions are not ruled by any gene.

# %% [markdown]
# ## look at a spefic reaction and compare data to its web infomation

# %%
# http://bigg.ucsd.edu/models/iND750/reactions/13BGH
for reaction in models['reactions']:
    if reaction['id'] == '13BGH':
        print(reaction)

# %% [markdown]
# The useful attribute here is *'metabolites'*,

# %%
for gene in models['genes']:
    if gene['id'] == 'YGR282C':
        print(gene)

# %% [markdown]
# ## Data Preparation

# %%
# step 1: find one gene
# step 2: find the reactions which are ruled by this gene
# step 3: find the substrate (< 0) and products (> 0) of one of these reactions. Repeat for all reactions ruled by this gene.
# step 4: repeat above steps for all genes -- every gene has a list of substrates and products.
# step 5: if a product of gene A is a substrate of gene B, then gene A and gene B has a connection

# %%
genes = {}
inorganics = []
for gene in models['genes']:
    genes[gene['id']] = {}
    genes[gene['id']]['reactions'] = []
    genes[gene['id']]['substrates'] = []
    genes[gene['id']]['products'] = []
    for reaction in models['reactions']:
        if gene['id'] in reaction['gene_reaction_rule'] and gene['id'] not in genes[gene['id']]['reactions']:
            genes[gene['id']]['reactions'].append(reaction['id'])
            for metabolite, v in reaction['metabolites'].items():
                for m in models['metabolites']:
                    # exclude inorganic metabolites
                    try:
                        if 'C' in m['formula'] and m['formula'] not in ['CO2', 'CO', 'C']:
                            if v > 0 and metabolite not in genes[gene['id']]['products']:
                                genes[gene['id']]['products'].append(metabolite)
                            if v < 0 and metabolite not in genes[gene['id']]['substrates']:
                                genes[gene['id']]['substrates'].append(metabolite)
                        elif metabolite not in inorganics:
                            inorganics.append(metabolite)
                        else:
                            break
                    except KeyError:
                        print(m)
#                     if v == 1 and metabolite not in genes[gene['id']]['products']:
#                         genes[gene['id']]['products'].append(metabolite)
#                     if v == -1 and metabolite not in genes[gene['id']]['substrates']:
#                         genes[gene['id']]['substrates'].append(metabolite)
                            
for k0, v0 in genes.items():
    v0['links'] = []
    for product in v0['products']:
        for k1, v1 in genes.items():
            if k1 != k0 and product in v1['substrates']:
                v0['links'].append(k1)

# %%
inorganics
# Out:
# ['akg_c',
#  'glu__L_c',
#  'h2o_c',
#  'h_c',
#  'nad_c',
#  'nadh_c',
#  'nh4_c',
#  'nadp_c',
#  'nadph_c',
#  'akg_h',
#  'glu__L_h',
#  'h2o_h',
#  'h_h',
#  'nadp_h',
#  'nadph_h',
#  'nh4_h',
#  'gln__L_c',
#  'adp_c',
#  'atp_c',
#  'glyc3p_c',
#  'glyc_c',
#  '6pgc_c',
#  'glcn_c',
#  '2pg_c',
#  'glyc__R_c',
#  '3dsphgn_c',
#  'sphgn_c',
#  'indpyr_c',
#  'trp__L_c',
#  '34hpp_c',
#  'tyr__L_c',
#  '2kmb_c',
#  'met__L_c',
#  'phe__L_c',
#  'phpyr_c',
#  'his__L_c',
#  'impyr_c',
#  'aksuc_c',
#  'asn__L_c',
#  'asp__L_c',
#  'oaa_c',
#  '4h2oglt_c',
#  'e4hglu_c',
#  '3spyr_c',
#  'Lcyst_c',
#  '3sala_c',
#  '3snpyr_c',
#  'co2_m',
#  'gly_m',
#  'mlthf_m',
#  'nad_m',
#  'nadh_m',
#  'nh4_m',
#  'thf_m',
#  '5fthf_c',
#  'methf_c',
#  'dhpt_c',
#  'dhpt_e',
#  'h_e',
#  'fol_c',
#  'fol_e',
#  '4abz_c',
#  '4abz_e',
#  '5fthf_e',
#  '3hdecACP_h',
#  'tdec2eACP_h',
#  '3hddecACP_h',
#  'tddec2eACP_h',
#  '3hmrsACP_h',
#  'tmrs2eACP_h',
#  '3hpalmACP_h',
#  'tpalm2eACP_h',
#  '3haACP_h',
#  'but2eACP_h',
#  '3hhexACP_h',
#  'thex2eACP_h',
#  '3hoctACP_h',
#  'toct2eACP_h',
#  '3hibutcoa_c',
#  '3hmp_c',
#  'coa_c',
#  'amp_c',
#  'pi_c',
#  'adn_c',
#  'cdp_c',
#  'ctp_c',
#  'f6p_c',
#  'fru_c',
#  'g6p_c',
#  'glc__D_c',
#  'pyam5p_c',
#  'pydam_c',
#  'pdx5p_c',
#  'pydxn_c',
#  'pydx5p_c',
#  'pydx_c',
#  'thmmp_c',
#  'thmpp_c',
#  'thm_c',
#  '4nph_c',
#  '4nphp_c',
#  'gthrd_c',
#  'lac__D_c',
#  'lgt__S_c',
#  'aacoa_c',
#  'accoa_c',
#  'gthrd_h',
#  'lac__D_h',
#  'lgt__S_h',
#  'accoa_h',
#  'adp_h',
#  'atp_h',
#  'hco3_h',
#  'malcoa_h',
#  'pi_h',
#  'btamp_c',
#  'btn_c',
#  'ppi_c',
#  'hco3_c',
#  'malcoa_c',
#  '3odecACP_h',
#  '3oddecACP_h',
#  '3omrsACP_h',
#  '3opalmACP_h',
#  'actACP_h',
#  '3ohexACP_h',
#  '3ooctACP_h',
#  'gdpddman_c',
#  'gdpmann_c',
#  'gmp_c',
#  'xmp_c',
#  'co2_c',
#  'ru5p__D_c',
#  'alpa_pf_16_0_c',
#  'pmtcoa_c',
#  'alpa_pf_18_0_c',
#  'stcoa_c',
#  'alpa_pf_18_1_c',
#  'odecoa_c',
#  'alpa_pf_18_2_c',
#  'lnlccoa_c',
#  'alpa_pf_20_4_c',
#  'arachdcoa_c',
#  'chol_c',
#  'g3pc_c',
#  'etha_c',
#  'g3pe_c',
#  'g3pg_c',
#  'ACP_h',
#  'acACP_h',
#  'co2_h',
#  'malACP_h',
#  'ocACP_h',
#  'dcaACP_h',
#  'ddcaACP_h',
#  'myrsACP_h',
#  'butACP_h',
#  'hexACP_h',
#  'gacpail_pf_18_0_18_1_16_0_c',
#  'gpail_pf_18_0_18_1_c',
#  'dol11manp_r',
#  'dolp11_r',
#  'gacpail_pf_18_0_18_1_16_0_r',
#  'h_r',
#  'm4gacpail_pf_18_0_18_1_16_0_r',
#  'dol12manp_r',
#  'dolp12_r',
#  '23dpg_c',
#  '3pg_c',
#  'fdp_c',
#  'pep_c',
#  'pyr_c',
#  'grxox_c',
#  'grxrd_c',
#  'h2o2_c',
#  'gthox_c',
#  'plrxox_c',
#  'plrxrd_c',
#  'dadp_c',
#  'dgdp_c',
#  'gdp_c',
#  'dcdp_c',
#  'dudp_c',
#  'udp_c',
#  'trdox_c',
#  'trdrd_c',
#  'h2o2_m',
#  'h2o_m',
#  'trdox_m',
#  'trdrd_m',
#  'gthox_m',
#  'gthrd_m',
#  'accoa_m',
#  'acgam1p_c',
#  'acgam6p_c',
#  'gthox_e',
#  'gthrd_e',
#  'gthox_h',
#  'h_m',
#  'nadp_m',
#  'nadph_m',
#  'ac_c',
#  'acgpail_pf_18_0_18_1_c',
#  'r5p_c',
#  'h2o2_h',
#  'glucys_c',
#  'gly_c',
#  'seln_c',
#  'selnp_c',
#  'ahdt_c',
#  'for_c',
#  'gtp_c',
#  'ser__L_c',
#  'gdptp_c',
#  'ppgpp_c',
#  'pppi_c',
#  'p4a_c',
#  '35cgmp_c',
#  '5mta_c',
#  'ametam_c',
#  'ptrc_c',
#  'spmd_c',
#  'sprm_c',
#  'coa_h',
#  'gua_c',
#  'prpp_c',
#  'hxan_c',
#  'imp_c',
#  'xan_c',
#  'acon_C_m',
#  'cit_m',
#  'acon_C_c',
#  'cit_c',
#  'icit_c',
#  'icit_m',
#  'o2_c',
#  'o2s_c',
#  'Hb_l',
#  'hemeBo_l',
#  'polypep_l',
#  'ala__L_c',
#  'arg__L_c',
#  'cys__L_c',
#  'h2o_l',
#  'ile__L_c',
#  'leu__L_c',
#  'lys__L_c',
#  'pro__L_c',
#  'thr__L_c',
#  'val__L_c',
#  'o2_m',
#  'o2s_m',
#  'fum_m',
#  'q8_m',
#  'q8h2_m',
#  'succ_m',
#  'fad_m',
#  'fadh2_m',
#  'fmn_c',
#  'ribflv_c',
#  'apoACP_h',
#  'pap_h',
#  'ppa_c',
#  'ppcoa_c',
#  '13dpg_c',
#  'coa_m',
#  'gdp_m',
#  'gtp_m',
#  'pi_m',
#  'succoa_m',
#  'adp_m',
#  'atp_m',
#  'ins_c',
#  'dad_2_c',
#  'din_c',
#  '5mti_c',
#  '4adcho_c',
#  '3mob_c',
#  '3mop_c',
#  '4mop_c',
#  'chor_c',
#  'ade_c',
#  'ade_e',
#  'adn_e',
#  'gsn_c',
#  'gsn_e',
#  'gua_e',
#  'thym_c',
#  'thym_e',
#  'ura_c',
#  'ura_e',
#  'uri_c',
#  'uri_e',
#  'csn_c',
#  'csn_e',
#  'hxan_e',
#  'ins_e',
#  'thymd_c',
#  'thymd_e',
#  'camp_c',
#  'camp_e',
#  '35cgmp_e',
#  'dad_2_e',
#  'dgsn_c',
#  'dgsn_e',
#  'din_e',
#  'dttp_c',
#  'dttp_e',
#  'gly_e',
#  'thr__L_e',
#  'xan_e',
#  'damp_c',
#  'g3p_c',
#  's7p_c',
#  'xu5p__D_c',
#  'e4p_c',
#  '3ophb_m',
#  '4hbz_m',
#  'octdp_m',
#  'ppi_m',
#  'dhap_c',
#  'dhap_h',
#  'g3p_h',
#  'amp_m',
#  'ahcys_c',
#  'amet_c',
#  'hcys__L_c',
#  'hemeA_m',
#  'hemeO_m',
#  'ipdp_c',
#  'ttc_ggdp_c',
#  'udcpdp_c',
#  'orn_c',
#  'frdp_m',
#  'pheme_m',
#  'cpppg3_h',
#  'uppg3_h',
#  'cpppg1_h',
#  'uppg1_h',
#  '4mhetz_c',
#  '4mpetz_c',
#  'acglu_c',
#  'gam6p_c',
#  'gam_c',
#  'man6p_c',
#  'man_c',
#  'dcamp_c',
#  'fum_c',
#  '25aics_c',
#  'aicar_c',
#  'hmbil_h',
#  'ppbng_h',
#  'hmz_l',
#  '1p3h5c_c',
#  '4hpro_LT_c',
#  '1pyr5c_c',
#  'dsbcox_r',
#  'dsbcrd_r',
#  'gthox_r',
#  'gthrd_r',
#  'dsbgox_r',
#  'dsbgrd_r',
#  'pa_pf_16_0_16_0_c',
#  'pa_pf_16_0_18_0_c',
#  'pa_pf_16_0_18_1_c',
#  'pa_pf_16_0_18_2_c',
#  'pa_pf_18_0_18_0_c',
#  'pa_pf_18_0_18_1_c',
#  'pa_pf_18_1_18_1_c',
#  'pa_pf_18_1_18_2_c',
#  'pa_pf_18_2_18_2_c',
#  'pa_pf_18_0_20_4_c',
#  'pa_pf_18_1_20_4_c',
#  'pa_pf_20_4_20_4_c',
#  'pa_pf_16_0_20_4_c',
#  'akg_m',
#  'mal__L_c',
#  'mal__L_m',
#  'oaa_m',
#  'k_c',
#  'k_e',
#  'lac__L_c',
#  'succ_c',
#  'mercplac_c',
#  'mercppyr_c',
#  '4mop_m',
#  'ivcoa_m',
#  '3mob_m',
#  'ibcoa_m',
#  '2mbcoa_m',
#  '3mop_m',
#  'pyr_m',
#  'mthgxl_c',
#  'mthgxl_h',
#  'nad_h',
#  'nadh_h',
#  'pyr_h',
#  'dhnpt_c',
#  '5aop_m',
#  'ala__L_e',
#  'arg__L_e',
#  'cys__L_e',
#  'met__L_e',
#  'pro__L_e',
#  'trp__L_e',
#  'tyr__L_e',
#  'val__L_e',
#  'asn__L_e',
#  'gln__L_e',
#  'glu__L_e',
#  'his__L_e',
#  'ile__L_e',
#  'leu__L_e',
#  'lys__L_e',
#  'phe__L_e',
#  'ser__L_e',
#  'amet_e',
#  'Lcyst_e',
#  'chito2pdol_L_dolp11_c',
#  'naglc2p_L_dolp11_c',
#  'uacgam_c',
#  'chito2pdol_L_dolp12_c',
#  'naglc2p_L_dolp12_c',
#  'dolp11_c',
#  'ump_c',
#  'dolp12_c',
#  'lald__D_c',
#  '4pyrdx_c',
#  'mi1456p_c',
#  'mi145p_c',
#  'mi13456p_c',
#  'lipoamp_m',
#  'lipopb_m',
#  'lipoate_m',
#  'mi14p_c',
#  'octapb_h',
#  '2fe2s_h',
#  '4fe4s_h',
#  'amet_h',
#  'dad_5_h',
#  'fe2_h',
#  'lipopb_h',
#  'met__L_h',
#  'hdca_c',
#  'lpchol_pf_16_0_c',
#  'lpchol_pf_18_1_c',
#  'ocdcea_c',
#  'lnlc_c',
#  'lpchol_pf_18_2_c',
#  'arachd_c',
#  'lpchol_pf_20_4_c',
#  'lpe_pf_16_0_c',
#  'lpe_pf_18_1_c',
#  'lpe_pf_18_2_c',
#  'lpe_pf_20_4_c',
#  'acgam_c',
#  'chtn_c',
#  '15dap_c',
#  'psd5p_c',
#  'pail3p_pf_16_0_18_1_c',
#  'pail_pf_16_0_18_1_c',
#  'pail3p_pf_18_0_18_1_c',
#  'pail_pf_18_0_18_1_c',
#  'pail34p_pf_16_0_18_1_c',
#  'pail4p_pf_16_0_18_1_c',
#  'pail34p_pf_18_0_18_1_c',
#  'pail4p_pf_18_0_18_1_c',
#  'pail345p_pf_16_0_18_1_c',
#  'pail345p_pf_18_0_18_1_c',
#  'man1p_c',
#  'glyald_h',
#  'glyc_h',
#  'sbt__D_c',
#  'alltt_c',
#  'urdglyc_c',
#  'urea_c',
#  'dhcrm_pf_18_0_16_0_c',
#  'dhcrm_pf_18_0_18_0_c',
#  'dhcrm_pf_18_0_24_0_c',
#  'lgnccoa_c',
#  'cholp_g',
#  'crm_pf_18_1_18_0_g',
#  'h2o_g',
#  'h_g',
#  'sphymyln_pf_18_1_18_0_g',
#  'crm_pf_18_1_24_0_g',
#  'sphymyln_pf_18_1_24_0_g',
#  'crm_pf_18_1_16_0_g',
#  'sphymyln_pf_18_1_16_0_g',
#  'cyan_c',
#  'tcynt_c',
#  'dag_pf_16_0_16_0_g',
#  'pchol_pf_16_0_16_0_g',
#  'dag_pf_16_0_18_1_g',
#  'pchol_pf_16_0_18_1_g',
#  'dag_pf_16_0_18_0_g',
#  'pchol_pf_16_0_18_0_g',
#  'dag_pf_18_1_18_1_g',
#  'pchol_pf_18_1_18_1_g',
#  'dag_pf_18_1_18_2_g',
#  'pchol_pf_18_1_18_2_g',
#  'dag_pf_18_2_18_2_g',
#  'pchol_pf_18_2_18_2_g',
#  'amet_m',
#  'mql4_m',
#  'mqn4_m',
#  'cdpdag_pf_16_0_18_1_c',
#  'cmp_c',
#  'pgp_pf_16_0_18_1_c',
#  '2mecdp_h',
#  'h2mb4p_h',
#  'anth_c',
#  '2p4c2me_h',
#  'cmp_h',
#  'aopox_h',
#  'aoprd_h',
#  'plrxox_h',
#  'plrxrd_h',
#  'grxox_h',
#  'grxrd_h',
#  'clpn_pf_16_0_18_1_16_0_18_1_m',
#  'glyc_m',
#  'pglyc_pf_16_0_18_1_m',
#  '2me4p_h',
#  '4c2me_h',
#  'ctp_h',
#  'ppi_h',
#  'ap3a_c',
#  'saccrp__L_c',
#  '4hba_c',
#  'dxyl5p_c',
#  'mg2_c',
#  'mg2_e',
#  'ap4a_c',
#  'gp4g_c',
#  'up4u_c',
#  'utp_c',
#  'xp4x_c',
#  'xtp_c',
#  'inost_c',
#  'mi3p__D_c',
#  '10fthf_c',
#  'mlthf_c',
#  'cbasp_c',
#  'cbp_c',
#  'tdcoa_c',
#  'dnad_c',
#  'nac_c',
#  'nicrnt_c',
#  'fdox_h',
#  'fdred_h',
#  'dag_pf_16_0_18_1_c',
#  'mag160_c',
#  'dag_pf_18_0_18_1_c',
#  'mag180_c',
#  'dag_pf_18_0_18_2_c',
#  'mag181_c',
#  'dag_pf_16_0_18_0_c',
#  'ocdca_c',
#  'tag_pf_16_0_18_0_18_0_c',
#  'tag_pf_18_0_18_1_16_0_c',
#  'dag_pf_18_1_18_2_c',
#  'tag_pf_18_1_18_2_18_2_c',
#  'dag_pf_18_0_18_0_c',
#  'tag_pf_18_0_18_0_18_1_c',
#  'na1_c',
#  'na1_e',
#  'dgmp_c',
#  'dtdp_c',
#  'dgtp_c',
#  'dctp_c',
#  'datp_c',
#  'dutp_c',
#  'dag_pf_16_0_16_0_c',
#  'dag_pf_16_0_18_2_c',
#  'dag_pf_18_1_18_1_c',
#  'dag_pf_18_2_18_2_c',
#  'dag_pf_16_0_20_4_c',
#  'dag_pf_20_4_20_4_c',
#  'ahcys_h',
#  'horden_h',
#  'nmettyam_h',
#  'ncam_c',
#  'mmet_c',
#  'no2_m',
#  'h_l',
#  'chsterol_c',
#  'pchol_pf_16_0_20_4_c',
#  'xolest_16_0_c',
#  'pchol_pf_16_0_18_1_c',
#  'pchol_pf_16_0_18_2_c',
#  'Asn_X_Ser_Thr_c',
#  'doldp11_c',
#  'g3m8masn_c',
#  'doldp12_c',
#  'cu2_c',
#  'cu2_e',
#  '2ombzl_m',
#  '2ommbl_m',
#  'ahcys_m',
#  'fmet__L_c',
#  'orot5p_c',
#  'orot_c',
#  '2omph_m',
#  'glu5sa_c',
#  'cholp_c',
#  'pchol_pf_16_0_16_0_c',
#  'pchol_pf_18_1_18_1_c',
#  'pchol_pf_18_1_18_2_c',
#  'pchol_pf_18_2_18_2_c',
#  'ethamp_c',
#  'pe_pf_16_0_16_0_c',
#  'pe_pf_16_0_18_1_c',
#  'pe_pf_16_0_18_2_c',
#  'pe_pf_18_1_18_1_c',
#  'pe_pf_18_1_18_2_c',
#  'pe_pf_18_2_18_2_c',
#  'pail45p_pf_16_0_18_1_c',
#  'pail45p_pf_18_0_18_1_c',
#  '35cdamp_c',
#  '35cimp_c',
#  '35ccmp_c',
#  'adp_e',
#  'atp_e',
#  'cdpea_c',
#  'ca2_c',
#  'ca2_e',
#  'ca2_m',
#  'r1p_c',
#  'g1p_c',
#  '3hbcoa__R_c',
#  'cdpdag_pf_16_0_16_0_c',
#  'pail_pf_16_0_16_0_c',
#  'cdpdag_pf_16_0_18_0_c',
#  'pail_pf_16_0_18_0_c',
#  'cdpdag_pf_18_0_18_0_c',
#  'pail_pf_18_0_18_0_c',
#  'cdpdag_pf_18_0_18_1_c',
#  'cdpdag_pf_18_1_18_1_c',
#  'pail_pf_18_1_18_1_c',
#  'cdpdag_pf_18_0_20_4_c',
#  'cdpdag_pf_18_1_20_4_c',
#  'cdpdag_pf_20_4_20_4_c',
#  'cdpchol_c',
#  'pe_pf_20_4_20_4_c',
#  'pchol_pf_16_0_18_0_c',
#  '3psme_c',
#  'cl_c',
#  'cl_e',
#  'hco3_e',
#  'ni2_c',
#  'ni2_e',
#  'cobalt2_c',
#  'cobalt2_e',
#  'pi_e',
#  'cpppg3_c',
#  'pppg9_c',
#  'ficytC_m',
#  'focytC_m',
#  '4ppan_c',
#  'pnto__R_c',
#  'pnto__R_e',
#  '5aop_h',
#  '4ppcys_c',
#  'pan4p_c',
#  'ppp9_c',
#  'ppp9_m',
#  'pppg9_m',
#  'dcmp_c',
#  'lac__D_e',
#  'lac__L_e',
#  'pyr_e',
#  'skm5p_c',
#  'skm_c',
#  'ps_pf_18_1_18_1_c',
#  'ps_pf_20_4_20_4_c',
#  'ps_pf_18_0_18_1_c',
#  'ps_pf_18_0_20_4_c',
#  'ps_pf_18_1_20_4_c',
#  'no3_m',
#  '6pthp_c',
#  '6hmhpt_c',
#  'gcald_c',
#  '2ahhmp_c',
#  'dpcoa_c',
#  '2dr1p_c',
#  '5mdr1p_c',
#  'xtsn_c',
#  'pep_h',
#  'didp_c',
#  'dimp_c',
#  'dtmp_c',
#  'dump_c',
#  'dha_c',
#  'dha_e',
#  'glyc_e',
#  'h2o_e',
#  'mthgxl_e',
#  'nh4_e',
#  'dhf_c',
#  'thf_c',
#  '5thf_c',
#  '5mthf5glu_c',
#  '5mthf_c',
#  'dhor__S_m',
#  'orot_m',
#  'dhor__S_c',
#  '6hmhptpp_c',
#  '2ahhmd_c',
#  'dmpp_c',
#  'grdp_c',
#  'frdp_c',
#  'dmpp_h',
#  'ipdp_h',
#  '2omhmbl_m',
#  '2ohph_m',
#  'dna5mtc_c',
#  'dna_c',
#  'dol11manp_c',
#  'dol12manp_c',
#  'crm_pf_18_1_18_0_c',
#  'gluside_18_0_18_1_c',
#  'udpg_c',
#  'gluside_18_1_18_0_c',
#  'crm_pf_18_1_24_0_c',
#  'gluside_18_1_24_0_c',
#  'crm_pf_18_1_16_0_c',
#  'gluside_18_1_16_0_c',
#  'dolichol11_c',
#  'dolichol12_c',
#  'dpcoa_h',
#  '2dr5p_c',
#  'acald_c',
#  'dxyl5p_h',
#  'palmACP_h',
#  '2mp2coa_c',
#  '3mb2coa_c',
#  'hivcoa_c',
#  '2mb2coa_c',
#  '3hmbcoa_c',
#  'occoa_c',
#  'octa_c',
#  'dca_c',
#  'dcacoa_c',
#  'ddca_c',
#  'ddcacoa_c',
#  'tdecoa_c',
#  'ttdcea_c',
#  'hdcea_c',
#  'hdcoa_c',
#  'lgn_c',
#  'ttdca_c',
#  'fe2_m',
#  'fe2_c',
#  'fe2_e',
#  'fad_c',
#  'for_e',
#  'no2_c',
#  'no2_e',
#  'no3_c',
#  'no3_e',
#  'ggdp_c',
#  'fru_e',
#  'glc__D_e',
#  'man_e',
#  'glyc3p_h',
#  '6pgl_c',
#  'g6p_B_c',
#  'gdpfuc_c',
#  'hexdp_c',
#  'pendp_c',
#  'hepdp_c',
#  'octdp_c',
#  'gly_h',
#  'mlthf_h',
#  'ser__L_h',
#  'thf_h',
#  'ser__L_m']

# %%
df = pd.DataFrame.from_dict(genes).T
df
# Out:
#                                 reactions  \
# PBANKA_122820                    [GLUDxi]
# PBANKA_102620           [GLUDy, GDH_nadp]
# PBANKA_101400           [GLUDy, GDH_nadp]
# PBANKA_100950              [GLUSx, GLUSy]
# PBANKA_136430         [GLYK, GNK, GLYCK2]
# ...                                   ...
# PBANKA_030080    [PPTT, GGTT, OPP, HEXTT]
# PBANKA_145020  [GHMT2r, GHMT2rc, GHMT2rm]
# PBANKA_131980  [GHMT2r, GHMT2rc, GHMT2rm]
# PBANKA_082350                      [GLNS]
# PBANKA_081980                    [GLUCYS]
#
#                                                       substrates  \
# PBANKA_122820                           [glu__L_c, h2o_c, nad_c]
# PBANKA_102620  [glu__L_c, h2o_c, nadp_c, glu__L_h, h2o_h, nad...
# PBANKA_101400  [glu__L_c, h2o_c, nadp_c, glu__L_h, h2o_h, nad...
# PBANKA_100950            [akg_c, gln__L_c, h_c, nadh_c, nadph_c]
# PBANKA_136430                 [atp_c, glyc_c, glcn_c, glyc__R_c]
# ...                                                          ...
# PBANKA_030080        [ipdp_c, pendp_c, ggdp_c, hepdp_c, hexdp_c]
# PBANKA_145020  [ser__L_c, thf_c, ser__L_h, thf_h, ser__L_m, t...
# PBANKA_131980  [ser__L_c, thf_c, ser__L_h, thf_h, ser__L_m, t...
# PBANKA_082350                           [atp_c, glu__L_c, nh4_c]
# PBANKA_081980                        [atp_c, cys__L_c, glu__L_c]
#
#                                                         products  \
# PBANKA_122820                        [akg_c, h_c, nadh_c, nh4_c]
# PBANKA_102620  [akg_c, h_c, nadph_c, nh4_c, akg_h, h_h, nadph...
# PBANKA_101400  [akg_c, h_c, nadph_c, nh4_c, akg_h, h_h, nadph...
# PBANKA_100950                          [glu__L_c, nad_c, nadp_c]
# PBANKA_136430              [adp_c, glyc3p_c, h_c, 6pgc_c, 2pg_c]
# ...                                                          ...
# PBANKA_030080        [hexdp_c, ppi_c, pendp_c, octdp_c, hepdp_c]
# PBANKA_145020  [gly_c, h2o_c, mlthf_c, gly_h, h2o_h, mlthf_h,...
# PBANKA_131980  [gly_c, h2o_c, mlthf_c, gly_h, h2o_h, mlthf_h,...
# PBANKA_082350                       [adp_c, gln__L_c, h_c, pi_c]
# PBANKA_081980                       [adp_c, glucys_c, h_c, pi_c]
#
#                                                            links
# PBANKA_122820  [PBANKA_100950, PBANKA_030230, PBANKA_132210, ...
# PBANKA_102620  [PBANKA_100950, PBANKA_030230, PBANKA_132210, ...
# PBANKA_101400  [PBANKA_100950, PBANKA_030230, PBANKA_132210, ...
# PBANKA_100950  [PBANKA_122820, PBANKA_102620, PBANKA_101400, ...
# PBANKA_136430  [PBANKA_142130, PBANKA_040470, PBANKA_040220, ...
# ...                                                          ...
# PBANKA_030080  [PBANKA_144490, PBANKA_111240, PBANKA_050740, ...
# PBANKA_145020  [PBANKA_111180, PBANKA_136010, PBANKA_020990, ...
# PBANKA_131980  [PBANKA_111180, PBANKA_136010, PBANKA_020990, ...
# PBANKA_082350  [PBANKA_142130, PBANKA_040470, PBANKA_040220, ...
# PBANKA_081980  [PBANKA_142130, PBANKA_040470, PBANKA_040220, ...
#
# [448 rows x 4 columns]

# %%
True in df.index.str.contains('YDL157C')
# Out:
# False

# %%
df1 = pd.DataFrame({'index':df.index.repeat(df.links.str.len()), 'links':df.links.sum()})
df1
# Out:
#                index          links
# 0      PBANKA_122820  PBANKA_100950
# 1      PBANKA_122820  PBANKA_030230
# 2      PBANKA_122820  PBANKA_132210
# 3      PBANKA_122820  PBANKA_070670
# 4      PBANKA_122820  PBANKA_143870
# ...              ...            ...
# 22939  PBANKA_081980  PBANKA_121240
# 22940  PBANKA_081980  PBANKA_144490
# 22941  PBANKA_081980  PBANKA_060110
# 22942  PBANKA_081980  PBANKA_111300
# 22943  PBANKA_081980  PBANKA_132640
#
# [22944 rows x 2 columns]

# %%
# show genes having no links
print(df.loc[df['links'].str.len() == 0])
# Out:
#                             reactions  \
# PBANKA_135470  [GPIMT11er, GPIMT12er]
# PBANKA_010590    [UPPDC1_1, UPPDC2_1]
# PBANKA_131060                   [HMZ]
# PBANKA_092090    [DSBCGT_1, DSBGGT_1]
# PBANKA_092430    [DSBCGT_1, DSBGGT_1]
# PBANKA_133580    [DSBCGT_1, DSBGGT_1]
# PBANKA_132890                   [Kt1]
# PBANKA_082030    [DSBCGT_1, DSBGGT_1]
# PBANKA_070280    [DSBCGT_1, DSBGGT_1]
# PBANKA_136520    [DSBCGT_1, DSBGGT_1]
# PBANKA_091430    [DSBCGT_1, DSBGGT_1]
# PBANKA_080050               [CHTNASE]
# PBANKA_130440               [ALLTAHr]
# PBANKA_010800             [CLPNSm_pf]
# PBANKA_140270                  [MGt5]
# PBANKA_133440              [CLHCOtex]
# PBANKA_092790  [MGt5, NIt5, COBALTt5]
# PBANKA_101700  [MGt5, NIt5, COBALTt5]
# PBANKA_010770                  [FE2t]
#
#                                                       substrates  \
# PBANKA_135470  [dol11manp_r, gacpail_pf_18_0_18_1_16_0_r, dol...
# PBANKA_010590                            [h_h, uppg3_h, uppg1_h]
# PBANKA_131060                                         [hemeBo_l]
# PBANKA_092090                      [dsbcox_r, gthrd_r, dsbgox_r]
# PBANKA_092430                      [dsbcox_r, gthrd_r, dsbgox_r]
# PBANKA_133580                      [dsbcox_r, gthrd_r, dsbgox_r]
# PBANKA_132890                                              [k_e]
# PBANKA_082030                      [dsbcox_r, gthrd_r, dsbgox_r]
# PBANKA_070280                      [dsbcox_r, gthrd_r, dsbgox_r]
# PBANKA_136520                      [dsbcox_r, gthrd_r, dsbgox_r]
# PBANKA_091430                      [dsbcox_r, gthrd_r, dsbgox_r]
# PBANKA_080050                                    [chtn_c, h2o_c]
# PBANKA_130440                                   [alltt_c, h2o_c]
# PBANKA_010800                             [pglyc_pf_16_0_18_1_m]
# PBANKA_140270                                            [mg2_c]
# PBANKA_133440                                     [cl_e, hco3_c]
# PBANKA_092790                          [mg2_c, ni2_c, cobalt2_c]
# PBANKA_101700                          [mg2_c, ni2_c, cobalt2_c]
# PBANKA_010770                                            [fe2_e]
#
#                                                         products links
# PBANKA_135470  [dolp11_r, h_r, m4gacpail_pf_18_0_18_1_16_0_r,...    []
# PBANKA_010590                        [co2_h, cpppg3_h, cpppg1_h]    []
# PBANKA_131060                                            [hmz_l]    []
# PBANKA_092090                      [dsbcrd_r, gthox_r, dsbgrd_r]    []
# PBANKA_092430                      [dsbcrd_r, gthox_r, dsbgrd_r]    []
# PBANKA_133580                      [dsbcrd_r, gthox_r, dsbgrd_r]    []
# PBANKA_132890                                              [k_c]    []
# PBANKA_082030                      [dsbcrd_r, gthox_r, dsbgrd_r]    []
# PBANKA_070280                      [dsbcrd_r, gthox_r, dsbgrd_r]    []
# PBANKA_136520                      [dsbcrd_r, gthox_r, dsbgrd_r]    []
# PBANKA_091430                      [dsbcrd_r, gthox_r, dsbgrd_r]    []
# PBANKA_080050                                          [acgam_c]    []
# PBANKA_130440                                [urdglyc_c, urea_c]    []
# PBANKA_010800            [clpn_pf_16_0_18_1_16_0_18_1_m, glyc_m]    []
# PBANKA_140270                                            [mg2_e]    []
# PBANKA_133440                                     [cl_c, hco3_e]    []
# PBANKA_092790                          [mg2_e, ni2_e, cobalt2_e]    []
# PBANKA_101700                          [mg2_e, ni2_e, cobalt2_e]    []
# PBANKA_010770                                            [fe2_c]    []

# %%
G = nx.from_pandas_edgelist(df=df1, source='index', target='links')

# %%
# get subgraphs
def connected_component_subgraphs(G):
    for c in nx.connected_components(G):
        yield G.subgraph(c)

# %%
giant = max(connected_component_subgraphs(G), key=len)

# %%
giant.number_of_nodes()
# Out:
# 431

# %% [markdown]
# ## Laplacian and Eigen

# %%
# Laplacian Matrix
L = nx.laplacian_matrix(giant, nodelist=sorted(giant.nodes()))
L.todense()
# Out:
# matrix([[  7,   0,   0, ...,   0,   0,   0],
#         [  0, 223,   0, ...,   0,  -1,  -1],
#         [  0,   0,   3, ...,   0,   0,   0],
#         ...,
#         [  0,   0,   0, ...,  29,   0,   0],
#         [  0,  -1,   0, ...,   0,  86,   0],
#         [  0,  -1,   0, ...,   0,   0,  86]], dtype=int64)

# %%
eig = np.linalg.eig(L.todense())
eig
# Out:
# (array([2.47263497e+02, 2.46246541e+02, 2.45863241e+02, 2.38146518e+02,
#         1.06781809e-13, 2.30242258e+02, 2.28240733e+02, 2.46000000e+02,
#         2.46000000e+02, 2.25770854e+02, 2.24116994e+02, 2.19730813e+02,
#         2.18119347e+02, 2.19008713e+02, 2.15746610e+02, 2.10544691e+02,
#         2.19000000e+02, 2.17000000e+02, 2.07340004e+02, 2.03560229e+02,
#         2.04377567e+02, 2.12000000e+02, 2.00679421e+02, 1.97444654e+02,
#         2.06000000e+02, 1.95277438e+02, 1.82871725e+02, 1.86489965e+02,
#         1.88244720e+02, 1.91148269e+02, 1.90837418e+02, 1.89176385e+02,
#         1.89818846e+02, 1.90064629e+02, 1.90014197e+02, 1.92000000e+02,
#         1.81493667e+02, 1.80076618e+02, 1.79750086e+02, 1.78344881e+02,
#         1.78119013e+02, 1.74216203e+02, 1.75737008e+02, 1.76351535e+02,
#         1.77032005e+02, 1.79000000e+02, 1.70997496e+02, 1.77000000e+02,
#         1.68440000e+02, 1.68093454e+02, 1.67761529e+02, 1.67040094e+02,
#         1.66446307e+02, 1.66010648e+02, 1.65531589e+02, 1.65298104e+02,
#         1.64208674e+02, 1.59994215e+02, 1.60259803e+02, 1.62917511e+02,
#         1.61032737e+02, 1.61484560e+02, 1.61976699e+02, 1.62025392e+02,
#         1.62010672e+02, 1.90000000e+02, 1.52834582e+02, 1.75000000e+02,
#         1.74000000e+02, 1.42017541e+02, 1.67000000e+02, 1.65000000e+02,
#         1.38944614e+02, 1.38059359e+02, 1.36411896e+02, 1.34015484e+02,
#         1.33653697e+02, 1.33067944e+02, 1.31115968e+02, 1.29828495e+02,
#         1.59000000e+02, 1.59000000e+02, 1.86000000e+02, 1.86000000e+02,
#         1.38000000e+02, 1.86000000e+02, 1.86000000e+02, 1.29000000e+02,
#         1.25129186e+02, 1.22309870e+02, 1.20748578e+02, 1.20282402e+02,
#         1.18042555e+02, 1.17308270e+02, 1.15554958e+02, 1.13487094e+02,
#         1.12188933e+02, 1.11934161e+02, 1.19000000e+02, 1.27000000e+02,
#         1.27000000e+02, 8.37718872e-01, 9.82367285e-01, 9.88511643e-01,
#         9.94964397e-01, 1.80936148e+00, 1.99199338e+00, 2.22724948e+00,
#         1.00000000e+00, 4.79675485e+00, 4.47169883e+00, 3.75039003e+00,
#         2.75730999e+00, 2.90307736e+00, 3.00933961e+00, 2.93375755e+00,
#         2.95285470e+00, 2.96886264e+00, 2.98073594e+00, 1.86000000e+02,
#         1.86000000e+02, 1.86000000e+02, 1.08229596e+02, 1.07388932e+02,
#         1.05047200e+02, 1.09000000e+02, 1.03957035e+02, 1.03370073e+02,
#         1.01916597e+02, 5.87051680e+00, 5.91147085e+00, 6.14727660e+00,
#         6.61251590e+00, 6.88954873e+00, 7.20951393e+00, 7.09866587e+00,
#         7.05106208e+00, 8.58966226e+00, 8.42582789e+00, 7.62086092e+00,
#         7.85445880e+00, 7.79654782e+00, 1.25000000e+02, 1.09000000e+02,
#         1.01461235e+02, 1.00511935e+02, 1.00389478e+02, 1.00237782e+02,
#         1.00177298e+02, 9.96925329e+01, 9.86405504e+01, 9.82316329e+01,
#         9.79491684e+01, 9.77783290e+01, 5.67715339e+01, 5.55262260e+01,
#         5.46751648e+01, 5.13224155e+01, 6.06532184e+01, 6.12589350e+01,
#         4.76387267e+01, 4.63506942e+01, 7.99540288e+00, 8.92967658e+00,
#         9.09450420e+00, 9.53852413e+00, 9.85678696e+00, 1.00479049e+01,
#         1.05853688e+01, 1.06723883e+01, 1.07956002e+01, 1.25000000e+02,
#         9.73481613e+01, 6.24922646e+01, 4.58630898e+01, 4.36266932e+01,
#         4.32457178e+01, 1.14271810e+01, 1.15375199e+01, 3.09964209e+01,
#         3.22995828e+01, 3.31739195e+01, 2.97458690e+01, 2.88055470e+01,
#         2.77664480e+01, 2.67409023e+01, 2.61585971e+01, 2.54284019e+01,
#         9.01470332e+01, 8.92333834e+01, 4.28750007e+01, 1.22883997e+01,
#         1.08138166e+01, 2.51796083e+01, 2.47658924e+01, 3.45984681e+01,
#         3.34902411e+01, 3.35945106e+01, 3.38911052e+01, 1.25000000e+02,
#         8.90385880e+01, 9.56089348e+01, 9.58189059e+01, 9.45047032e+01,
#         9.49175651e+01, 9.48118236e+01, 1.20422295e+01, 1.21117722e+01,
#         9.63253784e+01, 9.15004999e+01, 9.24569529e+01, 9.18108508e+01,
#         5.50000000e+01, 2.42336806e+01, 2.38804044e+01, 1.32519399e+01,
#         6.41442177e+01, 3.59335515e+01, 3.60534725e+01, 8.81341932e+01,
#         9.21300342e+01, 9.36631967e+01, 9.34388777e+01, 9.62486955e+01,
#         9.62122446e+01, 4.19186576e+01, 2.35466060e+01, 2.30718072e+01,
#         2.28741589e+01, 2.20709969e+01, 3.81175949e+01, 3.64761975e+01,
#         3.71398942e+01, 3.69254440e+01, 3.69478105e+01, 1.25000000e+02,
#         9.69913967e+01, 3.86574741e+01, 2.14561616e+01, 2.19345850e+01,
#         8.62420399e+01, 9.30580250e+01, 8.54806456e+01, 6.55680174e+01,
#         6.58616119e+01, 6.61792923e+01, 1.43627703e+01, 1.43941433e+01,
#         1.46088577e+01, 2.33403526e+01, 3.84417787e+01, 3.95643357e+01,
#         3.89788229e+01, 2.10152670e+01, 2.07883507e+01, 6.67883146e+01,
#         6.71010035e+01, 1.47311218e+01, 1.49401313e+01, 2.04636663e+01,
#         1.97522243e+01, 1.56947862e+01, 3.97482560e+01, 4.10187051e+01,
#         4.07536425e+01, 8.49504589e+01, 8.36252488e+01, 8.41247980e+01,
#         8.40010529e+01, 6.84007612e+01, 6.82340137e+01, 6.78093744e+01,
#         7.26664584e+01, 7.29331739e+01, 7.08006561e+01, 7.03640368e+01,
#         7.04228090e+01, 9.60499995e+01, 7.35380529e+01, 1.95253708e+01,
#         3.99022943e+01, 4.09266272e+01, 8.00000000e+00, 1.58575933e+01,
#         1.88054857e+01, 1.64829386e+01, 1.66276726e+01, 1.68163482e+01,
#         1.83287019e+01, 4.00093376e+01, 9.29855724e+01, 6.78776537e+01,
#         7.38479663e+01, 8.12604995e+01, 8.06100227e+01, 8.17936038e+01,
#         8.20119192e+01, 7.49412996e+01, 7.54278087e+01, 7.57657630e+01,
#         7.61555701e+01, 7.72295122e+01, 7.81931771e+01, 7.77793776e+01,
#         7.78642070e+01, 1.75000782e+01, 1.59807476e+01, 9.70064019e+01,
#         7.68906089e+01, 7.80524643e+01, 6.40000000e+01, 8.19284208e+01,
#         7.80878452e+01, 7.59896593e+01, 7.69992609e+01, 1.00000000e+01,
#         1.67476382e+01, 1.72750247e+01, 1.73329688e+01, 1.85233986e+01,
#         1.79732330e+01, 1.81081448e+01, 1.78779555e+01, 1.78678081e+01,
#         2.90000000e+01, 7.00000000e+00, 1.20000000e+01, 3.50000000e+01,
#         3.40000000e+01, 5.20000000e+01, 4.60000000e+01, 4.40000000e+01,
#         6.60000000e+01, 6.70000000e+01, 7.00000000e+01, 7.10000000e+01,
#         8.00000000e+01, 9.60000000e+01, 1.02000000e+02, 1.02000000e+02,
#         1.10000000e+01, 5.20000000e+01, 7.00000000e+00, 1.86000000e+02,
#         9.80000000e+01, 9.40000000e+01, 9.70000000e+01, 9.10000000e+01,
#         8.60000000e+01, 2.60000000e+01, 1.50000000e+01, 2.00000000e+01,
#         8.40000000e+01, 8.10000000e+01, 4.00000000e+01, 4.10000000e+01,
#         4.60000000e+01, 4.40000000e+01, 1.10000000e+01, 1.60000000e+01,
#         1.90000000e+01, 1.70000000e+01, 1.80000000e+01, 2.60000000e+01,
#         4.10000000e+01, 1.02000000e+02, 9.80000000e+01, 5.20000000e+01,
#         9.10000000e+01, 8.60000000e+01, 7.60000000e+01, 7.80000000e+01,
#         7.70000000e+01, 6.80000000e+01, 6.80000000e+01, 7.40000000e+01,
#         7.40000000e+01, 8.40000000e+01, 8.10000000e+01, 8.20000000e+01,
#         8.20000000e+01, 1.86000000e+02, 4.40000000e+01, 1.70000000e+01,
#         2.60000000e+01, 1.60000000e+01, 1.80000000e+01, 8.00000000e+01,
#         7.80000000e+01, 5.20000000e+01, 7.40000000e+01, 4.60000000e+01,
#         4.60000000e+01, 4.60000000e+01, 1.86000000e+02, 1.86000000e+02,
#         1.10000000e+01, 9.60000000e+01, 1.02000000e+02, 4.00000000e+01,
#         9.10000000e+01, 8.60000000e+01, 6.80000000e+01, 8.10000000e+01,
#         4.10000000e+01, 4.40000000e+01, 4.60000000e+01, 1.02000000e+02,
#         2.60000000e+01, 9.10000000e+01, 9.10000000e+01, 8.60000000e+01,
#         4.40000000e+01, 8.60000000e+01, 8.60000000e+01, 8.60000000e+01,
#         5.20000000e+01, 5.20000000e+01, 4.60000000e+01, 4.60000000e+01,
#         5.20000000e+01, 5.20000000e+01, 5.20000000e+01, 4.60000000e+01,
#         4.60000000e+01, 4.60000000e+01, 5.20000000e+01, 5.20000000e+01,
#         5.20000000e+01, 5.20000000e+01, 5.20000000e+01]),
#  matrix([[-5.69353742e-04,  2.36922313e-04,  5.50947195e-04, ...,
#            1.67030229e-18, -7.21462576e-20, -1.09431863e-18],
#          [-3.41205812e-04, -5.77717736e-04, -3.44547893e-03, ...,
#            5.38275208e-18,  3.72857630e-18, -8.65987483e-18],
#          [ 5.27884995e-04, -5.33361408e-05, -1.92712749e-04, ...,
#           -2.96625938e-17, -5.06669031e-18, -1.64683947e-16],
#          ...,
#          [ 1.83306820e-03,  3.45967844e-04,  2.87600685e-04, ...,
#           -9.60413555e-17,  6.25105215e-17, -1.10828713e-16],
#          [ 2.21716465e-02, -9.29029386e-03, -2.14177697e-02, ...,
#           -3.84909064e-16,  6.19385403e-17,  2.41423789e-16],
#          [ 2.21716465e-02, -9.29029386e-03, -2.14177697e-02, ...,
#            1.76097229e-16, -2.26860576e-16, -3.60609216e-17]]))

# %% [markdown]
# ## Plotting

# %%
def draw_sub(k, eig, G, layout, ccmap, vmin, vmax):
    i = np.argpartition(eig[0], k)[k]
    v = eig[1].real[:, i].T.tolist()[0]
    # node_color is the coefficient of eigenvectors 
    nx.draw(G, layout, node_size=100, node_color=v, edge_color="#cccccc", edgecolors='#000000', cmap=ccmap, vmin=vmin, vmax=vmax)
    plt.axis('off')
    sm = plt.cm.ScalarMappable(cmap=ccmap, norm=plt.Normalize(vmin=vmin, vmax=vmax))
    sm.set_array([])
#     plt.colorbar(sm)
#     plt.title('k = {}'.format(k))

# %%
def change_scale(eig):
    # smallest coefficient
    vmin = np.amin(eig[1])
    # largest coefficient
    vmax = np.amax(eig[1])
    if vmin*vmax < 0:
        v = max(abs(vmin), abs(vmax))
        vmin = -v
        vmax = v
    # if vmin and vmax have the same sign, the colorbar can't be symmetrical.
    return vmin, vmax

# %% [markdown]
# ## Make Color Map

# %%
from matplotlib import cm
from matplotlib.colors import ListedColormap
from matplotlib.colors import LinearSegmentedColormap
winter = cm.get_cmap('winter', 128)
autumn = cm.get_cmap('autumn_r', 128)

newcolors = np.vstack((winter(np.linspace(0, 1, 128)),
                       autumn(np.linspace(0, 1, 128))))
ccmap = ListedColormap(newcolors, name='OrangeBlue')

# %%
plt.rc('figure', figsize=(30, 30))
K = 5/np.sqrt(giant.order())
layout = nx.spring_layout(G, k=K, seed=3)

# %% [markdown]
# ## Plot

# %%
n0 = 4
n_sub = n0 ** 2
base = len(eig[0]) // (n_sub - 2)
k_lst0 = [0, 1]
k_lst1 = [x * base for x in range(1, n_sub-2)]
k_lst2 = [len(eig[0])-1]
k_lst = k_lst0 + k_lst1 + k_lst2
vmin, vmax = change_scale(eig)
for i, k in enumerate(k_lst):
#     plt.subplot(n0, n0, i+1)
    draw_sub(k, eig, giant, layout, ccmap, vmin, vmax)
    plt.savefig('../output/{}.png'.format(k))
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## Size vs index

# %%
import os
import collections
f_name = os.listdir('../output/')
f_name = [str(pre)+'.png' for pre in sorted([int(os.path.splitext(f)[0]) for f in f_name if '.png' in f])]
size_dict = dict()
for f in f_name:
    size_dict[os.path.splitext(f)[0]] = os.path.getsize('../output/{}'.format(f))
size_dict
# Out:
# {'0': 1017714,
#  '1': 926648,
#  '30': 826697,
#  '60': 756013,
#  '90': 691719,
#  '120': 654953,
#  '150': 611412,
#  '180': 583578,
#  '210': 560282,
#  '240': 540628,
#  '270': 527060,
#  '300': 508922,
#  '330': 497485,
#  '360': 483917,
#  '390': 473283,
#  '430': 458743}

# %%
index_lst = [int(i)/len(eig[1]) for i in list(size_dict.keys())]
index_lst
# Out:
# [0.0,
#  0.002320185614849188,
#  0.06960556844547564,
#  0.13921113689095127,
#  0.2088167053364269,
#  0.27842227378190254,
#  0.3480278422273782,
#  0.4176334106728538,
#  0.4872389791183295,
#  0.5568445475638051,
#  0.6264501160092807,
#  0.6960556844547564,
#  0.765661252900232,
#  0.8352668213457076,
#  0.9048723897911833,
#  0.9976798143851509]

# %%
size_lst = list(size_dict.values())
s_lst = [s - min(size_lst) for s in size_lst]
s_lst = [s / max(s_lst) for s in s_lst]
s_lst
# Out:
# [1.0,
#  0.8370827824699314,
#  0.6582702859361219,
#  0.5318164985303352,
#  0.4167944311958939,
#  0.3510199992486193,
#  0.27312508162319693,
#  0.22333001175374034,
#  0.18165343103667275,
#  0.14649239405979916,
#  0.12221922067513341,
#  0.08977031008764319,
#  0.06930949906166867,
#  0.04503632567700292,
#  0.02601208291664505,
#  0.0]

# %%
plt.plot(index_lst, s_lst)
